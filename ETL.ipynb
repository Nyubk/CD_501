# %% [markdown]
# <a href="https://colab.research.google.com/github/Nyubk/CD_501/blob/main/ETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("dailyActivity.csv")
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
ds_ts = pd.read_csv("dailyActivity.csv")
df_ts.DataFrame  =  ds_ts
ds_ts
#df_ts.head()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df_ts1= df_ts.copy()
df_ts1.drop_duplicates()
df_ts1.drop(labels="LoggedActivitiesDistance", axis=1, errors= 'ignore'   )
df_ts1.drop(df_ts[(df_ts["TotalSteps"] == 0)].index, inplace=True)
df_ts1.sort_values(by="TotalSteps")
df_ts1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# ...

# %%
ndf_ts= df_ts.loc[:,["ActivityDate","TotalSteps","Calories"]]
ndf_ts["Calories/TotalSteps"] = df_ts["TotalSteps"]/ df_ts["Calories"]

# %%
ndf_ts.to_csv("df_train.csv")
pd.read_csv("df_train.csv")
# Out:
#      Unnamed: 0 ActivityDate  TotalSteps  Calories  Calories/TotalSteps
# 0             0    3/25/2016       11004      1819             6.049478
# 1             1    3/26/2016       17609      2154             8.175023
# 2             2    3/27/2016       12736      1944             6.551440
# 3             3    3/28/2016       13231      1932             6.848344
# 4             4    3/29/2016       12041      1886             6.384411
# ..          ...          ...         ...       ...                  ...
# 391         452     4/8/2016       23014      4196             5.484747
# 392         453     4/9/2016       16470      3841             4.287946
# 393         454    4/10/2016       28497      4526             6.296288
# 394         455    4/11/2016       10622      2820             3.766667
# 395         456    4/12/2016        2350       938             2.505330
#
# [396 rows x 5 columns]
